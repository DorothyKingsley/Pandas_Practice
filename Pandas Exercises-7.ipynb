# %% [markdown]
# # Pandas Exercise: Basic Stats (Wind Statistics)

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/guipsamora/pandas_exercises/blob/master/Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
#regex as a seperator
data=pd.read_csv("wind.data",sep='\s+\-*\s*')
data['date'] = pd.to_datetime(data.Yr*10000+data.Mo*100+data.Dy,format='%y%m%d')
data.drop(['Yr','Mo','Dy'],axis=1,inplace=True)
#data.set_index('date',inplace=True)
data=data[['date','RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']]
data.to_csv("joes.csv")
# Out:
# /Users/dorothyjeyson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
from datetime import timedelta, date
col = 'date'
data[col] = pd.to_datetime(data[col])
future = data[col] > date(year=2060,month=1,day=1)
data.loc[future, col] -= timedelta(days=365.25*100)
data
# Out:
# /Users/dorothyjeyson/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   after removing the cwd from sys.path.
#            date    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# 5    1961-01-06  13.21   8.12   9.96   6.67   5.37   4.50  10.67   4.42
# ...

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.set_index('date',inplace=True)
data.index.astype('datetime64[ns]')
data
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# 1961-01-06  13.21   8.12   9.96   6.67   5.37   4.50  10.67   4.42   7.17
# 1961-01-07  13.50  14.29   9.50   4.96  12.29   8.33   9.17   9.29   7.58
# 1961-01-08  10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62   9.25
# 1961-01-09  12.58  10.83  10.00   4.75  10.37   6.79   8.04  10.13   7.79
# 1961-01-10  13.37  11.12  19.50   8.33   9.71   6.54  11.42   7.79   8.54
# 1961-01-11  10.58   9.87   8.42   2.79   8.71   7.25   7.54   8.33   5.71
# 1961-01-12  19.75  12.08  18.50  10.54  10.29   9.46  15.54  11.50  10.37
# ...

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isna().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.count()
#data.info()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats=pd.DataFrame(data.describe()).T
#loc_stats=loc_stats.T
loc_stats.drop(['count','25%','50%','75%'],inplace=True,axis=1)
loc_stats
# Out:
#           mean       std   min    max
# RPT  12.362987  5.618413  0.67  35.80
# VAL  10.644314  5.267356  0.21  33.37
# ROS  11.660526  5.008450  1.50  33.84
# KIL   6.306468  3.605811  0.00  28.46
# SHA  10.455834  4.936125  0.13  37.54
# BIR   7.092254  3.968683  0.00  26.16
# DUB   9.797343  4.977555  0.00  30.37
# CLA   8.495053  4.499449  0.00  31.08
# MUL   8.493590  4.166872  0.00  25.88
# CLO   8.707332  4.503954  0.04  28.21
# BEL  13.121007  5.835037  0.13  42.38
# MAL  15.599079  6.699794  0.67  42.54

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats=((data.T.describe()).T)
day_stats.drop(['count','25%','50%','75%'],inplace=True,axis=1)
day_stats
# Out:
#                  mean       std    min    max
# date
# 1961-01-01  13.018182  2.808875   9.29  18.50
# 1961-01-02  11.336364  3.188994   6.50  17.54
# 1961-01-03  11.641818  3.681912   6.17  18.50
# 1961-01-04   6.619167  3.198126   1.79  11.75
# 1961-01-05  10.630000  2.445356   6.17  13.33
# 1961-01-06   8.240000  2.998063   4.42  13.21
# 1961-01-07  10.385000  3.072114   4.96  14.29
# 1961-01-08  10.487500  3.547237   5.91  16.62
# 1961-01-09   9.897500  2.905954   4.75  15.37
# 1961-01-10  10.477500  3.442610   6.54  19.50
# 1961-01-11   9.625000  4.805082   2.79  20.71
# 1961-01-12  13.524167  3.375046   9.46  19.75
# 1961-01-13   4.277500  2.916349   0.58   9.92
# 1961-01-14   3.975833  2.788833   0.50   9.04
# 1961-01-15   6.695000  3.276740   2.37  12.04
# 1961-01-16  10.164167  3.521277   4.71  16.42
# 1961-01-17  13.621667  2.874739   8.71  17.75
# 1961-01-18  15.348182  4.128786   8.79  20.79
# 1961-01-19   4.111667  2.171325   1.04   7.83
# ...

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
#data.groupby(data['date'].dt.strftime('%B'))
#data.groupby(pd.Grouper(key='date',freq='M'))
data.loc[data.index.month==1].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
yearly=data.resample('A').sum()
yearly
# Out:
#                 RPT      VAL      ROS      KIL      SHA      BIR      DUB  \
# date
# 1961-12-31  4427.85  3747.35  4124.54  2511.92  3950.08  2821.35  3523.68
# 1962-12-31  4457.88  3690.31  4282.44  2533.60  3890.14  2698.47  4022.56
# 1963-12-31  4676.91  3955.50  4577.52  2675.47  4279.30  3078.67  4042.63
# 1964-12-31  4525.10  3996.78  4430.20  2484.33  4192.34  2770.94  3754.85
# 1965-12-31  4544.75  4042.57  4324.80  2503.34  4024.05  2729.51  3875.83
# 1966-12-31  4913.62  4218.38  4387.53  2681.19  4308.84  2844.69  3861.63
# 1967-12-31  4649.06  4011.71  4284.88  2607.35  4245.22  2689.38  3887.99
# 1968-12-31  4331.84  3831.36  4175.97  2370.83  3938.44  2220.64  3242.46
# 1969-12-31  4075.72  3549.15  3979.23  2105.31  3603.98  2259.34  3126.04
# 1970-12-31  4599.12  3915.33  4281.54  2269.27  3857.09  2777.45  3507.61
# 1971-12-31  4114.69  3319.74  4047.24  1913.15  3445.72  2225.46  3060.85
# 1972-12-31  4561.81  3865.44  4413.35  2170.27  3451.53  2327.33  3551.85
# ...

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
monthly=data.resample('M').sum()
monthly
# Out:
#                RPT     VAL     ROS     KIL     SHA     BIR     DUB     CLA  \
# date
# 1961-01-31  445.24  359.65  416.38  239.84  321.11  266.23  346.73  277.36
# 1961-02-28  455.54  419.31  389.92  249.23  387.86  306.25  332.94  331.69
# 1961-03-31  326.70  350.19  333.34  218.52  325.79  274.87  298.97  304.72
# 1961-04-30  321.68  282.83  299.94  174.92  253.05  194.85  207.76  212.84
# 1961-05-31  305.69  265.50  335.36  177.16  294.20  203.82  228.12  253.49
# 1961-06-30  287.22  255.61  266.01  182.49  324.72  201.22  272.87  265.48
# 1961-07-31  329.04  254.87  282.42  196.57  326.51  192.15  250.60  256.81
# 1961-08-31  361.05  314.15  320.41  212.22  394.17  261.70  312.91  324.29
# 1961-09-30  375.93  280.05  312.53  207.51  330.10  217.02  246.18  259.16
# 1961-10-31  428.69  338.39  379.33  252.80  367.83  258.35  347.02  287.43
# 1961-11-30  326.89  257.78  355.51  181.37  273.71  187.52  315.22  189.41
# ...

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
weekly=data.resample('W').sum()
weekly
# Out:
#                RPT     VAL     ROS    KIL     SHA     BIR     DUB     CLA  \
# date
# 1961-01-01   15.04   14.96   13.17   9.29    0.00    9.87   13.67   10.25
# 1961-01-08   94.79   68.92   73.41  44.92   66.32   45.05   77.43   39.70
# 1961-01-15   87.28   62.77   83.71  32.41   51.46   35.51   52.75   47.74
# 1961-01-22   92.43   69.04   90.88  44.30   53.80   51.92   64.80   55.13
# 1961-01-29  119.28  112.99  127.58  89.04  122.03  103.80  108.70  106.12
# 1961-02-05  117.79  108.22   88.33  57.73   93.53   63.75   85.43   59.84
# 1961-02-12  137.79  114.92  121.13  75.42  103.03   87.66  104.54  103.95
# 1961-02-19  105.91  105.64   96.58  60.50   93.87   83.08   66.80   84.90
# 1961-02-26  106.55   95.38  100.34  59.67   95.59   70.80   78.05   76.13
# 1961-03-05   84.71   90.66   66.38  54.84   84.71   64.67   71.63   77.91
# 1961-03-12   56.26   81.05   75.92  49.96   76.58   66.42   48.17   67.46
# 1961-03-19   83.38   94.51   81.25  49.59   75.26   60.57   70.29   71.54
# ...

# %% [markdown]
# ### Step 15. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
monthly.T.mean()
# Out:
# date
# 1961-01-31    346.136667
# 1961-02-28    375.966667
# 1961-03-31    338.398333
# 1961-04-30    252.335000
# 1961-05-31    276.442500
# 1961-06-30    289.028333
# 1961-07-31    278.380833
# 1961-08-31    331.397500
# 1961-09-30    296.455833
# 1961-10-31    353.745833
# 1961-11-30    268.654167
# 1961-12-31    335.897500
# 1962-01-31    376.095833
# 1962-02-28    380.395833
# 1962-03-31    282.351667
# 1962-04-30    303.557500
# 1962-05-31    317.380833
# 1962-06-30    311.313333
# 1962-07-31    265.171667
# 1962-08-31    315.036667
# 1962-09-30    270.970000
# 1962-10-31    271.958333
# 1962-11-30    260.987500
# 1962-12-31    418.631667
# 1963-01-31    353.347500
# 1963-02-28    341.530000
# 1963-03-31    379.030833
# 1963-04-30    350.009167
# 1963-05-31    369.525000
# 1963-06-30    287.519167
#                  ...
# 1976-07-31    237.180833
# 1976-08-31    179.421667
# 1976-09-30    285.732500
# 1976-10-31    281.726667
# 1976-11-30    262.455833
# ...

# %% [markdown]
# ### Step 16. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
week_stats=(weekly.T.describe().T)
week_stats.drop(['count','25%','50%','75%'],inplace=True,axis=1)
week_stats
# Out:
#                   mean        std    min     max
# date
# 1961-01-01   11.933333   4.614681   0.00   18.50
# 1961-01-08   67.425000  18.665854  39.70   94.79
# 1961-01-15   58.472500  19.037546  32.41   87.28
# 1961-01-22   64.831667  15.929948  44.30   92.43
# 1961-01-29  117.050000  19.379127  89.04  157.71
# 1961-02-05   82.602500  19.651171  57.73  117.79
# 1961-02-12  111.240833  22.031887  75.42  152.83
# 1961-02-19   95.247500  22.975869  60.50  148.17
# 1961-02-26   88.230000  16.550263  59.67  114.13
# 1961-03-05   79.417500  18.261704  54.84  124.90
# 1961-03-12   73.506667  19.789498  48.17  116.91
# 1961-03-19   82.294167  23.242226  49.59  135.45
# 1961-03-26   73.240000  21.503822  46.54  126.94
# 1961-04-02   70.397500  14.528849  43.80   97.30
# 1961-04-09   65.886667  16.798883  41.71   95.25
# 1961-04-16   47.919167  12.626817  34.63   66.38
# 1961-04-23   71.026667  13.271604  54.38   95.34
# 1961-04-30   52.115000  13.048908  33.61   70.82
# ...
