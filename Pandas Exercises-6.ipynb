# %% [markdown]
# # Pandas Exercise: Merging (MPG Cars)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv).

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1=pd.read_csv("cars1.csv")
cars2=pd.read_csv("cars2.csv")

# %% [markdown]
# ### Step 4. Ops it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.dropna(axis=1,how='all',inplace=True)
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print("Number of observations in cars1 : ",cars1.shape[0])
print("Number of observations in cars2 : ",cars2.shape[0])
# Out:
# Number of observations in cars1 :  198
# Number of observations in cars2 :  200

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
frames=[cars1,cars2]
cars=pd.concat(frames,axis=0)
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %% [markdown]
# ### Step 7. Ops there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
cars3=pd.DataFrame()
cars3['owners']=np.random.randint(15000,73000,cars.shape[0])
cars3
# Out:
#      owners
# 0     59082
# 1     65572
# 2     64009
# 3     31523
# 4     26585
# 5     26096
# 6     35007
# 7     65788
# 8     50199
# 9     34548
# 10    44969
# 11    37465
# 12    19327
# 13    24920
# 14    43953
# 15    50988
# 16    58741
# 17    28818
# 18    69980
# 19    35303
# 20    61322
# 21    49324
# 22    43833
# 23    50178
# 24    24023
# 25    31120
# 26    49013
# 27    41141
# 28    22658
# 29    67343
# ..      ...
# 368   68501
# 369   30315
# 370   59695
# 371   61421
# 372   47082
# 373   15899
# 374   60065
# 375   56687
# 376   48222
# 377   31549
# 378   33098
# 379   27532
# 380   37183
# 381   59724
# 382   50968
# 383   70737
# 384   65251
# 385   72920
# 386   58188
# 387   55601
# 388   20978
# 389   21349
# 390   17598
# 391   24497
# 392   50215
# 393   32267
# 394   41084
# 395   35015
# 396   63030
# 397   15641
#
# [398 rows x 1 columns]

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
frames=(cars,cars3)
cars['owners']=cars3['owners']
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...
