# %% [markdown]
# # Pandas Exercise: Apply function (Student Alcohol Consumption)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Download the dataset from this [address](http://archive.ics.uci.edu/ml/datasets/STUDENT+ALCOHOL+CONSUMPTION).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
stud_por=pd.read_csv('student-por.csv')

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
stud_por_sl=stud_por.loc[:,'school':'guardian']
stud_por_sl
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
(lambda x: x.str.capitalize() if(x.dtype=='object') else x)
def to_capital(x):
    if x.dtype=='object':
        x.str.capitalize()
    else:
        X
    return x

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
stud_por_s1u = stud_por_sl.apply(lambda x: x.str.capitalize() if x.name in ["Mjob","Fjob"] else x)
stud_por_s1u
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# 5       GP   M   16       U     LE3       T     4     3  Services     Other
# 6       GP   M   16       U     LE3       T     2     2     Other     Other
# 7       GP   F   17       U     GT3       A     4     4     Other   Teacher
# 8       GP   M   15       U     LE3       A     3     2  Services     Other
# 9       GP   M   15       U     GT3       T     3     4     Other     Other
# 10      GP   F   15       U     GT3       T     4     4   Teacher    Health
# ...

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
stud_por[-1:]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob   Fjob  ...  \
# 648     MS   M   18       R     LE3       T     3     2  services  other  ...
#
#     famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 648      4        4      1     3     4      5        4  10  11  11
#
# [1 rows x 33 columns]

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
stud_por_s1=stud_por_sl.apply(lambda x: x.str.capitalize() if x.name in ["Mjob","Fjob"] else x)
stud_por_s1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# 5       GP   M   16       U     LE3       T     4     3  Services     Other
# 6       GP   M   16       U     LE3       T     2     2     Other     Other
# 7       GP   F   17       U     GT3       A     4     4     Other   Teacher
# 8       GP   M   15       U     LE3       A     3     2  Services     Other
# 9       GP   M   15       U     GT3       T     3     4     Other     Other
# 10      GP   F   15       U     GT3       T     4     4   Teacher    Health
# ...

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
stud_por_sl.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian'],
#       dtype='object')

# %%
def majority(age):
    if(age>18):
        return True
    else:
        return False
stud_por_sl["legal_drinker"]=stud_por_sl.apply(lambda x: majority(x.age),axis=1)
stud_por_sl
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
student=stud_por.apply(lambda x: x*10 if x.dtype=="int64" else x)
student
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F  180       U     GT3       A    40    40   at_home   teacher
# 1       GP   F  170       U     GT3       T    10    10   at_home     other
# 2       GP   F  150       U     LE3       T    10    10   at_home     other
# 3       GP   F  150       U     GT3       T    40    20    health  services
# 4       GP   F  160       U     GT3       T    30    30     other     other
# 5       GP   M  160       U     LE3       T    40    30  services     other
# 6       GP   M  160       U     LE3       T    20    20     other     other
# 7       GP   F  170       U     GT3       A    40    40     other   teacher
# 8       GP   M  150       U     LE3       A    30    20  services     other
# 9       GP   M  150       U     GT3       T    30    40     other     other
# 10      GP   F  150       U     GT3       T    40    40   teacher    health
# ...
